# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pyomo.environ import *

# %%
lego_info = pd.read_csv("LEGO_set.csv")

# %%
cust_info = pd.read_excel(open('customer.xlsx','rb'), sheet_name='customer')

# %%
inventory_info = pd.read_excel(open('customer.xlsx','rb'), sheet_name='inventory')
inventory_list = inventory_info.loc[:, "inventory"].values.tolist()
#len(inventory_list)

# %%
quantity_list = cust_info.loc[:, "quantity"].values.tolist()

# %%
price_limit = cust_info.loc[:, "price limit"].values.tolist()
#price_limit

# %%
lego_price = lego_info.loc[:, "list_price"].values.tolist()

# %%
play_rating = lego_info.loc[:, "play_star_rating"].values.tolist()

# %%
star_rating = lego_info.loc[:, "star_rating"].values.tolist()

# %%
customer_list = cust_info.loc[:, "item 1":].values.tolist()
#customer_list

# %%
model = ConcreteModel()
model.x = Var(range(len(lego_info)), range(len(customer_list)), domain = Binary)

# %%
#inventory constraint
model.inventory = ConstraintList()
for i in range(len(lego_info)):
    model.inventory.add(expr=sum(model.x[i,j] for j in range(len(customer_list))) <= inventory_list[i])

#customer will not get item that they already have    
model.newsample = ConstraintList()
for j in range(len(customer_list)):
    for i in range(len(lego_info)):
        model.newsample.add(expr=(model.x[i,j] + customer_list[j][i]) <= 1)

#the quantity of lego set should be the same as customer wanted
model.itemcount = ConstraintList()
for j in range(len(customer_list)):
    model.itemcount.add(expr = sum(model.x[i,j] for i in range(len(lego_info))) == quantity_list[j])

#the contraint of price
model.price = ConstraintList()
for j in range(len(customer_list)):
    model.price.add(expr = sum(model.x[i,j]*lego_price[i] for i in range(len(lego_info))) <= price_limit[j])

model.objective = Objective(expr = sum(model.x[i,j]*((play_rating[i]+star_rating[i])/2) for i in range(len(lego_info)) for j in range(len(customer_list))), sense= maximize)
opt = SolverFactory('glpk')
results = opt.solve(model, tee=True)
# Out:
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /var/folders/_7/44t0xrr57mx_nrg2qskcmmt40000gn/T/tmpmj31_ygb.glpk.raw
#  --wglp /var/folders/_7/44t0xrr57mx_nrg2qskcmmt40000gn/T/tmpz4qbaoq0.glpk.glp
#  --cpxlp /var/folders/_7/44t0xrr57mx_nrg2qskcmmt40000gn/T/tmpi_sii31e.pyomo.lp
# Reading problem data from '/var/folders/_7/44t0xrr57mx_nrg2qskcmmt40000gn/T/tmpi_sii31e.pyomo.lp'...
# /var/folders/_7/44t0xrr57mx_nrg2qskcmmt40000gn/T/tmpi_sii31e.pyomo.lp:902713: warning: lower bound of variable 'x1' redefined
# /var/folders/_7/44t0xrr57mx_nrg2qskcmmt40000gn/T/tmpi_sii31e.pyomo.lp:902713: warning: upper bound of variable 'x1' redefined
# 100901 rows, 100001 columns, 400001 non-zeros
# 100000 integer variables, all of which are binary
# 1002713 lines were read
# Writing problem data to '/var/folders/_7/44t0xrr57mx_nrg2qskcmmt40000gn/T/tmpz4qbaoq0.glpk.glp'...
# 801808 lines were written
# GLPK Integer Optimizer, v4.65
# 100901 rows, 100001 columns, 400001 non-zeros
# 100000 integer variables, all of which are binary
# Preprocessing...
# 4 hidden covering inequaliti(es) were detected
# 682 rows, 88341 columns, 228607 non-zeros
# 88341 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  8.540e+02  ratio =  8.540e+02
# GM: min|aij| =  2.413e-01  max|aij| =  4.144e+00  ratio =  1.717e+01
# EQ: min|aij| =  5.824e-02  max|aij| =  1.000e+00  ratio =  1.717e+01
# 2N: min|aij| =  4.527e-02  max|aij| =  1.749e+00  ratio =  3.864e+01
# Constructing initial basis...
# Size of triangular part is 682
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 682 rows, 88341 columns, 228607 non-zeros
#       0: obj =   4.814750000e+03 inf =   1.415e+03 (317)
#    1020: obj =   4.723352802e+03 inf =   5.600e-16 (0) 2
# *  3104: obj =   5.350000000e+03 inf =   1.332e-15 (0) 1
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +  3104: mip =     not found yet <=              +inf        (1; 0)
# Solution found by heuristic: 5349.9
# +  3123: >>>>>   5.350000000e+03 <=   5.350000000e+03 < 0.1% (9; 9)
# +  3123: mip =   5.350000000e+03 <=     tree is empty   0.0% (0; 35)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   3.1 secs
# Memory used: 113.7 Mb (119233692 bytes)
# Writing MIP solution to '/var/folders/_7/44t0xrr57mx_nrg2qskcmmt40000gn/T/tmpmj31_ygb.glpk.raw'...
# 200911 lines were written

# %%
model.solutions.store_to(results)
print(results.Solution.Objective["objective"]["Value"])
# Out:
# 5350.0

# %%
prod_id = lego_info.loc[:, "prod_id"].values.tolist()
prod_name = lego_info.loc[:, "set_name"].values.tolist()
customer_id = cust_info.loc[:, "customer"].values.tolist()
rating_id = []
for i in range(len(customer_id)):
    rating_id.append(str(customer_id[i]) + "rating")
result_dict = {}
each_list = []
each_avg_rating = 0
total_rating = 0
for j in range(len(customer_list)):
    for i in range(len(lego_info)):
        if model.x[i,j]() == 1:
            each_list.append(str(int(prod_id[i])) + ":" + str(prod_name[i]))
            each_avg_rating += (play_rating[i] + star_rating[i])/2
    result_dict[customer_id[j]] = each_list
    result_dict[rating_id[j]] = each_avg_rating/len(each_list)
    each_list = []
    each_avg_rating = 0

# %%
result_dict
# Out:
# {1: ['31059:Sunset Street Bike',
#   '41323:Snow Resort Chalet',
#   "41316:Andrea's Speedboat Transporter",
#   '42072:WHACK!',
#   '45502:EV3 Large Servo Motor',
#   '45506:EV3 Color Sensor',
#   '10857:Piston Cup Race'],
#  '1rating': 5.0,
#  2: ['10592:Fire Truck',
#   "41151:Mulan's Training Day",
#   "41316:Andrea's Speedboat Transporter",
#   '42072:WHACK!',
#   '45502:EV3 Large Servo Motor',
#   '45506:EV3 Color Sensor',
#   '10857:Piston Cup Race',
#   '21143:The Nether Portal'],
#  '2rating': 5.0,
#  3: ['40171:LEGO® Friends Buildable Hedgehog Storage',
#   '31071:Drone Explorer',
#   '75887:Porsche 919 Hybrid',
#   "10748:Emma's Pet Party"],
#  '3rating': 5.0,
#  4: ['31059:Sunset Street Bike',
#   "41316:Andrea's Speedboat Transporter",
#   '42072:WHACK!',
#   '45506:EV3 Color Sensor',
#   '10857:Piston Cup Race',
#   '10847:Number Train',
#   '10847:Number Train',
#   '60180:Monster Truck',
#   '70637:Cole - Spinjitzu Master',
#   '76096:Superman™ & Krypto™ Team-Up'],
#  '4rating': 5.0,
#  5: ["41316:Andrea's Speedboat Transporter",
#   '40171:LEGO® Friends Buildable Hedgehog Storage',
#   "10748:Emma's Pet Party",
#   '31071:Drone Explorer'],
#  '5rating': 5.0,
#  6: ['31059:Sunset Street Bike',
#   '41323:Snow Resort Chalet',
#   "41316:Andrea's Speedboat Transporter",
#   '42072:WHACK!',
#   '45502:EV3 Large Servo Motor',
#   '45506:EV3 Color Sensor'],
#  '6rating': 5.0,
#  7: ['40171:LEGO® Friends Buildable Hedgehog Storage'],
#  '7rating': 5.0,
#  8: ['40171:LEGO® Friends Buildable Hedgehog Storage'],
#  '8rating': 5.0,
#  9: ['31059:Sunset Street Bike',
#   '10813:Big Construction Site',
#   '10847:Number Train',
#   '70637:Cole - Spinjitzu Master',
#   '31071:Drone Explorer'],
#  '9rating': 5.0,
#  10: ['42072:WHACK!',
#   '10847:Number Train',
#   '60180:Monster Truck',
#   '21141:The Zombie Cave'],
#  '10rating': 5.0,
#  11: ['31059:Sunset Street Bike',
#   "41151:Mulan's Training Day",
#   '42072:WHACK!',
#   '45506:EV3 Color Sensor',
#   '10847:Number Train',
#   '10847:Number Train',
#   '60180:Monster Truck',
#   '70637:Cole - Spinjitzu Master',
#   '76096:Superman™ & Krypto™ Team-Up'],
#  '11rating': 5.0,
#  12: ['10592:Fire Truck',
#   '41323:Snow Resort Chalet',
#   '42072:WHACK!',
#   '45502:EV3 Large Servo Motor',
#   '45506:EV3 Color Sensor'],
#  '12rating': 5.0,
#  13: ["41316:Andrea's Speedboat Transporter"],
#  '13rating': 5.0,
#  14: ['10592:Fire Truck',
#   '31059:Sunset Street Bike',
#   '41323:Snow Resort Chalet',
#   "41316:Andrea's Speedboat Transporter",
#   '42072:WHACK!'],
#  '14rating': 5.0,
#  15: ["41151:Mulan's Training Day",
#   '42072:WHACK!',
#   '45506:EV3 Color Sensor',
#   '10847:Number Train',
#   '10847:Number Train',
#   '60180:Monster Truck',
#   '70637:Cole - Spinjitzu Master',
#   '76096:Superman™ & Krypto™ Team-Up',
#   '40171:LEGO® Friends Buildable Hedgehog Storage'],
#  '15rating': 5.0,
#  16: ["41316:Andrea's Speedboat Transporter",
#   '10698:LEGO® Large Creative Brick Box',
#   '42072:WHACK!',
#   '45502:EV3 Large Servo Motor',
#   '45502:EV3 Large Servo Motor',
#   '45506:EV3 Color Sensor',
#   '10857:Piston Cup Race',
#   '10847:Number Train',
#   '10847:Number Train',
#   '10744:Thunder Hollow Crazy 8 Race'],
#  '16rating': 5.0,
#  17: ["41316:Andrea's Speedboat Transporter",
#   '40171:LEGO® Friends Buildable Hedgehog Storage'],
#  '17rating': 5.0,
#  18: ['10592:Fire Truck',
#   '31059:Sunset Street Bike',
#   '41323:Snow Resort Chalet',
#   "41316:Andrea's Speedboat Transporter",
#   '42072:WHACK!',
#   '45502:EV3 Large Servo Motor',
#   '45506:EV3 Color Sensor'],
#  '18rating': 5.0,
#  19: ['40171:LEGO® Friends Buildable Hedgehog Storage',
#   '42072:WHACK!',
#   "10748:Emma's Pet Party"],
#  '19rating': 5.0,
#  20: ["41316:Andrea's Speedboat Transporter",
#   '40171:LEGO® Friends Buildable Hedgehog Storage',
#   '42072:WHACK!',
#   '31071:Drone Explorer',
#   '75887:Porsche 919 Hybrid',
#   "10732:Guido and Luigi's Pit Stop",
#   '41606:Star-Lord',
#   "10748:Emma's Pet Party",
#   '40171:LEGO® Friends Buildable Hedgehog Storage',
#   '70637:Cole - Spinjitzu Master'],
#  '20rating': 5.0,
#  21: ['10592:Fire Truck',
#   '40171:LEGO® Friends Buildable Hedgehog Storage',
#   '42072:WHACK!'],
#  '21rating': 5.0,
#  22: ['10592:Fire Truck',
#   '31059:Sunset Street Bike',
#   '10698:LEGO® Large Creative Brick Box',
#   '42072:WHACK!',
#   '45502:EV3 Large Servo Motor',
#   '45502:EV3 Large Servo Motor',
#   '45506:EV3 Color Sensor',
#   '10857:Piston Cup Race',
#   '10847:Number Train',
#   '10744:Thunder Hollow Crazy 8 Race'],
#  '22rating': 5.0,
#  23: ['40171:LEGO® Friends Buildable Hedgehog Storage',
#   '31071:Drone Explorer'],
#  '23rating': 5.0,
#  24: ['10592:Fire Truck',
#   '41323:Snow Resort Chalet',
#   "41316:Andrea's Speedboat Transporter",
#   '42072:WHACK!',
#   '45502:EV3 Large Servo Motor'],
#  '24rating': 5.0,
#  25: ["41316:Andrea's Speedboat Transporter"],
#  '25rating': 5.0,
#  26: ['31059:Sunset Street Bike',
#   '40171:LEGO® Friends Buildable Hedgehog Storage',
#   '31071:Drone Explorer',
#   '75887:Porsche 919 Hybrid'],
#  '26rating': 5.0,
#  27: ['10592:Fire Truck',
#   '41323:Snow Resort Chalet',
#   "41316:Andrea's Speedboat Transporter",
#   '10698:LEGO® Large Creative Brick Box',
#   '42072:WHACK!',
#   '45502:EV3 Large Servo Motor',
#   '45502:EV3 Large Servo Motor'],
#  '27rating': 5.0,
#  28: ['40171:LEGO® Friends Buildable Hedgehog Storage',
#   '75887:Porsche 919 Hybrid',
#   '41190:Emily Jones & the Eagle Getaway'],
#  '28rating': 5.0,
#  29: ["10732:Guido and Luigi's Pit Stop",
#   '41606:Star-Lord',
#   "10748:Emma's Pet Party",
#   "10732:Guido and Luigi's Pit Stop",
#   '31071:Drone Explorer',
#   '70637:Cole - Spinjitzu Master',
#   "10748:Emma's Pet Party"],
#  '29rating': 5.0,
#  30: ['40171:LEGO® Friends Buildable Hedgehog Storage'],
#  '30rating': 5.0,
#  31: ['31059:Sunset Street Bike',
#   '41323:Snow Resort Chalet',
#   "41316:Andrea's Speedboat Transporter",
#   '42072:WHACK!',
#   '45502:EV3 Large Servo Motor'],
#  '31rating': 5.0,
#  32: ['10592:Fire Truck',
#   '41323:Snow Resort Chalet',
#   "41316:Andrea's Speedboat Transporter",
#   '42072:WHACK!',
#   '10813:Big Construction Site',
#   '45502:EV3 Large Servo Motor',
#   '10847:Number Train',
#   '70637:Cole - Spinjitzu Master'],
#  '32rating': 5.0,
#  33: ['40171:LEGO® Friends Buildable Hedgehog Storage',
#   '42072:WHACK!',
#   '31071:Drone Explorer'],
#  '33rating': 5.0,
#  34: ["41316:Andrea's Speedboat Transporter", '45502:EV3 Large Servo Motor'],
#  '34rating': 5.0,
#  35: ["41316:Andrea's Speedboat Transporter",
#   '40171:LEGO® Friends Buildable Hedgehog Storage',
#   '42072:WHACK!',
#   "10748:Emma's Pet Party",
#   '31071:Drone Explorer'],
#  '35rating': 5.0,
#  36: ['40171:LEGO® Friends Buildable Hedgehog Storage'],
#  '36rating': 5.0,
#  37: ['40171:LEGO® Friends Buildable Hedgehog Storage'],
#  '37rating': 5.0,
#  38: ['31059:Sunset Street Bike',
#   "41316:Andrea's Speedboat Transporter",
#   '10698:LEGO® Large Creative Brick Box',
#   '42072:WHACK!',
#   '45502:EV3 Large Servo Motor',
#   '45502:EV3 Large Servo Motor'],
#  '38rating': 5.0,
#  39: ["41151:Mulan's Training Day",
#   '42072:WHACK!',
#   '45506:EV3 Color Sensor',
#   '10847:Number Train',
#   '10847:Number Train',
#   '60180:Monster Truck',
#   '70637:Cole - Spinjitzu Master',
#   '76096:Superman™ & Krypto™ Team-Up'],
#  '39rating': 5.0,
#  40: ['40171:LEGO® Friends Buildable Hedgehog Storage', '42072:WHACK!'],
#  '40rating': 5.0,
#  41: ['31059:Sunset Street Bike',
#   '41323:Snow Resort Chalet',
#   "41316:Andrea's Speedboat Transporter",
#   '42072:WHACK!',
#   '45502:EV3 Large Servo Motor',
#   '45506:EV3 Color Sensor',
#   '10857:Piston Cup Race',
#   '10847:Number Train',
#   '76096:Superman™ & Krypto™ Team-Up',
#   '10878:Rapunzel´s Tower'],
#  '41rating': 5.0,
#  42: ['31071:Drone Explorer',
#   '75887:Porsche 919 Hybrid',
#   "10748:Emma's Pet Party",
#   '31071:Drone Explorer'],
#  '42rating': 5.0,
#  43: ["41316:Andrea's Speedboat Transporter", '45502:EV3 Large Servo Motor'],
#  '43rating': 5.0,
#  44: ['10592:Fire Truck',
#   '31059:Sunset Street Bike',
#   "41151:Mulan's Training Day",
#   '42072:WHACK!',
#   '45506:EV3 Color Sensor',
#   '10847:Number Train',
#   '10847:Number Train',
#   '60180:Monster Truck',
#   '70637:Cole - Spinjitzu Master',
#   '76096:Superman™ & Krypto™ Team-Up'],
#  '44rating': 5.0,
#  45: ['10592:Fire Truck',
#   '31059:Sunset Street Bike',
#   '41323:Snow Resort Chalet',
#   "41316:Andrea's Speedboat Transporter",
#   '42072:WHACK!'],
#  '45rating': 5.0,
#  46: ['10592:Fire Truck',
#   '31059:Sunset Street Bike',
#   '41323:Snow Resort Chalet',
#   "41316:Andrea's Speedboat Transporter",
#   '42072:WHACK!',
#   '45502:EV3 Large Servo Motor'],
#  '46rating': 5.0,
#  47: ['31059:Sunset Street Bike',
#   '40171:LEGO® Friends Buildable Hedgehog Storage',
#   '42072:WHACK!',
#   '31071:Drone Explorer'],
#  '47rating': 5.0,
#  48: ['40171:LEGO® Friends Buildable Hedgehog Storage'],
#  '48rating': 5.0,
#  49: ['40171:LEGO® Friends Buildable Hedgehog Storage',
#   '42072:WHACK!',
#   "10748:Emma's Pet Party",
#   '31071:Drone Explorer'],
#  '49rating': 5.0,
#  50: ["41316:Andrea's Speedboat Transporter",
#   '40171:LEGO® Friends Buildable Hedgehog Storage',
#   '42072:WHACK!',
#   "10732:Guido and Luigi's Pit Stop",
#   '41606:Star-Lord',
#   "10748:Emma's Pet Party",
#   '40171:LEGO® Friends Buildable Hedgehog Storage',
#   '70637:Cole - Spinjitzu Master'],
#  '50rating': 5.0,
#  51: ['31059:Sunset Street Bike',
#   '41323:Snow Resort Chalet',
#   "41316:Andrea's Speedboat Transporter",
#   '45502:EV3 Large Servo Motor',
#   '45506:EV3 Color Sensor',
#   '10857:Piston Cup Race',
#   '60180:Monster Truck',
#   '70637:Cole - Spinjitzu Master',
#   '76096:Superman™ & Krypto™ Team-Up'],
#  '51rating': 5.0,
#  52: ['10592:Fire Truck',
#   '31059:Sunset Street Bike',
#   '41323:Snow Resort Chalet',
#   "41316:Andrea's Speedboat Transporter",
#   '42072:WHACK!'],
#  '52rating': 5.0,
#  53: ["41316:Andrea's Speedboat Transporter",
#   '40171:LEGO® Friends Buildable Hedgehog Storage',
#   '42072:WHACK!',
#   "10732:Guido and Luigi's Pit Stop",
#   '41606:Star-Lord',
#   "10748:Emma's Pet Party",
#   '40171:LEGO® Friends Buildable Hedgehog Storage',
#   '70637:Cole - Spinjitzu Master'],
#  '53rating': 5.0,
#  54: ['10592:Fire Truck',
#   '31059:Sunset Street Bike',
#   '41323:Snow Resort Chalet',
#   "41316:Andrea's Speedboat Transporter",
#   '42072:WHACK!',
#   '45502:EV3 Large Servo Motor',
#   '45506:EV3 Color Sensor',
#   '10857:Piston Cup Race'],
#  '54rating': 5.0,
#  55: ['10592:Fire Truck',
#   '31059:Sunset Street Bike',
#   "41151:Mulan's Training Day",
#   "41316:Andrea's Speedboat Transporter",
#   '42072:WHACK!',
#   '60180:Monster Truck',
#   '31071:Drone Explorer'],
#  '55rating': 5.0,
#  56: ['10592:Fire Truck',
#   '41323:Snow Resort Chalet',
#   "41316:Andrea's Speedboat Transporter",
#   '10698:LEGO® Large Creative Brick Box',
#   '45502:EV3 Large Servo Motor',
#   '45502:EV3 Large Servo Motor',
#   '45506:EV3 Color Sensor',
#   '10857:Piston Cup Race',
#   '10847:Number Train',
#   '10744:Thunder Hollow Crazy 8 Race'],
#  '56rating': 5.0,
#  57: ['10592:Fire Truck',
#   '31059:Sunset Street Bike',
#   '41323:Snow Resort Chalet',
#   "41316:Andrea's Speedboat Transporter",
#   '42072:WHACK!',
#   '45502:EV3 Large Servo Motor'],
#  '57rating': 5.0,
#  58: ['10592:Fire Truck',
#   '31059:Sunset Street Bike',
#   '41323:Snow Resort Chalet',
#   "41316:Andrea's Speedboat Transporter",
#   '10698:LEGO® Large Creative Brick Box',
#   '42072:WHACK!'],
#  '58rating': 5.0,
#  59: ['31059:Sunset Street Bike',
#   '40171:LEGO® Friends Buildable Hedgehog Storage',
#   '31071:Drone Explorer',
#   '75887:Porsche 919 Hybrid'],
#  '59rating': 5.0,
#  60: ['10592:Fire Truck',
#   '41323:Snow Resort Chalet',
#   "41316:Andrea's Speedboat Transporter",
#   '45502:EV3 Large Servo Motor',
#   '45506:EV3 Color Sensor',
#   '10857:Piston Cup Race',
#   '10847:Number Train',
#   '70637:Cole - Spinjitzu Master',
#   '21143:The Nether Portal'],
#  '60rating': 5.0,
#  61: ['10592:Fire Truck',
#   '31059:Sunset Street Bike',
#   '41323:Snow Resort Chalet',
#   "41316:Andrea's Speedboat Transporter",
#   '42072:WHACK!',
#   '45502:EV3 Large Servo Motor',
#   '45506:EV3 Color Sensor',
#   '10857:Piston Cup Race',
#   '10847:Number Train',
#   '10847:Number Train'],
#  '61rating': 5.0,
#  62: ['10592:Fire Truck',
#   '31059:Sunset Street Bike',
#   '41323:Snow Resort Chalet',
#   "41316:Andrea's Speedboat Transporter",
#   '42072:WHACK!'],
#  '62rating': 5.0,
#  63: ['10592:Fire Truck',
#   "41316:Andrea's Speedboat Transporter",
#   '45506:EV3 Color Sensor',
#   '10857:Piston Cup Race',
#   '10847:Number Train',
#   '70637:Cole - Spinjitzu Master',
#   '21143:The Nether Portal'],
#  '63rating': 5.0,
#  64: ['10592:Fire Truck',
#   '41323:Snow Resort Chalet',
#   "41151:Mulan's Training Day",
#   "41316:Andrea's Speedboat Transporter",
#   '10698:LEGO® Large Creative Brick Box',
#   '45506:EV3 Color Sensor',
#   '10847:Number Train',
#   '70637:Cole - Spinjitzu Master',
#   '40171:LEGO® Friends Buildable Hedgehog Storage',
#   "41151:Mulan's Training Day"],
#  '64rating': 5.0,
#  65: ['31059:Sunset Street Bike',
#   "41151:Mulan's Training Day",
#   '45506:EV3 Color Sensor',
#   '60180:Monster Truck',
#   '70637:Cole - Spinjitzu Master',
#   '76096:Superman™ & Krypto™ Team-Up',
#   '40171:LEGO® Friends Buildable Hedgehog Storage'],
#  '65rating': 5.0,
#  66: ['31059:Sunset Street Bike',
#   '41323:Snow Resort Chalet',
#   "41316:Andrea's Speedboat Transporter",
#   '45502:EV3 Large Servo Motor',
#   '45506:EV3 Color Sensor',
#   '10857:Piston Cup Race',
#   '60180:Monster Truck',
#   '70637:Cole - Spinjitzu Master',
#   '76096:Superman™ & Krypto™ Team-Up',
#   '21143:The Nether Portal'],
#  '66rating': 5.0,
#  67: ['40171:LEGO® Friends Buildable Hedgehog Storage'],
#  '67rating': 5.0,
#  68: ['10592:Fire Truck',
#   '31059:Sunset Street Bike',
#   '41323:Snow Resort Chalet',
#   "41316:Andrea's Speedboat Transporter",
#   '42072:WHACK!',
#   '45502:EV3 Large Servo Motor',
#   '45506:EV3 Color Sensor',
#   '10857:Piston Cup Race'],
#  '68rating': 5.0,
#  69: ['10592:Fire Truck',
#   "41151:Mulan's Training Day",
#   '45506:EV3 Color Sensor',
#   '10847:Number Train',
#   '70637:Cole - Spinjitzu Master',
#   '40171:LEGO® Friends Buildable Hedgehog Storage'],
#  '69rating': 5.0,
#  70: ['40171:LEGO® Friends Buildable Hedgehog Storage',
#   '31071:Drone Explorer',
#   '75887:Porsche 919 Hybrid'],
#  '70rating': 5.0,
#  71: ['10592:Fire Truck',
#   "41316:Andrea's Speedboat Transporter",
#   '40171:LEGO® Friends Buildable Hedgehog Storage',
#   '42072:WHACK!',
#   '75887:Porsche 919 Hybrid',
#   "10748:Emma's Pet Party",
#   '40171:LEGO® Friends Buildable Hedgehog Storage',
#   '31071:Drone Explorer',
#   '70637:Cole - Spinjitzu Master'],
#  '71rating': 5.0,
#  72: ['31059:Sunset Street Bike',
#   "41151:Mulan's Training Day",
#   '45506:EV3 Color Sensor',
#   '60180:Monster Truck',
#   '70637:Cole - Spinjitzu Master',
#   '40171:LEGO® Friends Buildable Hedgehog Storage'],
#  '72rating': 5.0,
#  73: ['40171:LEGO® Friends Buildable Hedgehog Storage', '42072:WHACK!'],
#  '73rating': 5.0,
#  74: ["41151:Mulan's Training Day",
#   '45506:EV3 Color Sensor',
#   '10847:Number Train',
#   '70637:Cole - Spinjitzu Master',
#   '40171:LEGO® Friends Buildable Hedgehog Storage',
#   "41151:Mulan's Training Day"],
#  '74rating': 5.0,
#  75: ['31059:Sunset Street Bike',
#   '40171:LEGO® Friends Buildable Hedgehog Storage',
#   '42072:WHACK!',
#   '31071:Drone Explorer'],
#  '75rating': 5.0,
#  76: ['40171:LEGO® Friends Buildable Hedgehog Storage',
#   '42072:WHACK!',
#   "10748:Emma's Pet Party",
#   '31071:Drone Explorer'],
#  '76rating': 5.0,
#  77: ['10592:Fire Truck',
#   '31059:Sunset Street Bike',
#   "41316:Andrea's Speedboat Transporter",
#   '42072:WHACK!',
#   '45506:EV3 Color Sensor',
#   '10857:Piston Cup Race',
#   '10847:Number Train'],
#  '77rating': 5.0,
#  78: ['10592:Fire Truck',
#   '31059:Sunset Street Bike',
#   '41323:Snow Resort Chalet',
#   "41316:Andrea's Speedboat Transporter",
#   '42072:WHACK!'],
#  '78rating': 5.0,
#  79: ['42072:WHACK!', '45506:EV3 Color Sensor', '10847:Number Train'],
#  '79rating': 5.0,
#  80: ["41316:Andrea's Speedboat Transporter",
#   '40171:LEGO® Friends Buildable Hedgehog Storage'],
#  '80rating': 5.0,
#  81: ['40171:LEGO® Friends Buildable Hedgehog Storage',
#   "10748:Emma's Pet Party"],
#  '81rating': 5.0,
#  82: ['10592:Fire Truck',
#   "41316:Andrea's Speedboat Transporter",
#   '40171:LEGO® Friends Buildable Hedgehog Storage',
#   '42072:WHACK!',
#   '31071:Drone Explorer'],
#  '82rating': 5.0,
#  83: ['40171:LEGO® Friends Buildable Hedgehog Storage'],
#  '83rating': 5.0,
#  84: ["41316:Andrea's Speedboat Transporter",
#   '10698:LEGO® Large Creative Brick Box',
#   '42072:WHACK!',
#   '45502:EV3 Large Servo Motor',
#   '45502:EV3 Large Servo Motor',
#   '45506:EV3 Color Sensor'],
#  '84rating': 5.0,
#  85: ['41323:Snow Resort Chalet',
#   "41316:Andrea's Speedboat Transporter",
#   '42072:WHACK!',
#   '45502:EV3 Large Servo Motor',
#   '45506:EV3 Color Sensor',
#   '10857:Piston Cup Race',
#   '10847:Number Train',
#   '10847:Number Train',
#   '60180:Monster Truck',
#   '70637:Cole - Spinjitzu Master'],
#  '85rating': 5.0,
#  86: ['41323:Snow Resort Chalet',
#   "41316:Andrea's Speedboat Transporter",
#   '42072:WHACK!',
#   '45502:EV3 Large Servo Motor',
#   '45506:EV3 Color Sensor',
#   '10857:Piston Cup Race'],
#  '86rating': 5.0,
#  87: ["41316:Andrea's Speedboat Transporter",
#   '40171:LEGO® Friends Buildable Hedgehog Storage'],
#  '87rating': 5.0,
#  88: ['31071:Drone Explorer', '75887:Porsche 919 Hybrid'],
#  '88rating': 5.0,
#  89: ['31059:Sunset Street Bike',
#   "41316:Andrea's Speedboat Transporter",
#   '10698:LEGO® Large Creative Brick Box',
#   '42072:WHACK!',
#   '45502:EV3 Large Servo Motor'],
#  '89rating': 5.0,
#  90: ['42072:WHACK!',
#   '45506:EV3 Color Sensor',
#   '10847:Number Train',
#   '10847:Number Train',
#   '60180:Monster Truck'],
#  '90rating': 5.0,
#  91: ["41316:Andrea's Speedboat Transporter"],
#  '91rating': 5.0,
#  92: ["41316:Andrea's Speedboat Transporter",
#   '40171:LEGO® Friends Buildable Hedgehog Storage',
#   '42072:WHACK!'],
#  '92rating': 5.0,
#  93: ["41151:Mulan's Training Day",
#   '42072:WHACK!',
#   '45506:EV3 Color Sensor',
#   '10847:Number Train',
#   '10847:Number Train',
#   '60180:Monster Truck',
#   '70637:Cole - Spinjitzu Master',
#   '40171:LEGO® Friends Buildable Hedgehog Storage'],
#  '93rating': 5.0,
#  94: ["41316:Andrea's Speedboat Transporter",
#   '40171:LEGO® Friends Buildable Hedgehog Storage',
#   "10748:Emma's Pet Party"],
#  '94rating': 5.0,
#  95: ['31071:Drone Explorer', '75887:Porsche 919 Hybrid'],
#  '95rating': 5.0,
#  96: ['40171:LEGO® Friends Buildable Hedgehog Storage'],
#  '96rating': 5.0,
#  97: ['40171:LEGO® Friends Buildable Hedgehog Storage',
#   '31071:Drone Explorer',
#   '75887:Porsche 919 Hybrid'],
#  '97rating': 5.0,
#  98: ['10592:Fire Truck',
#   '42072:WHACK!',
#   '45506:EV3 Color Sensor',
#   '10847:Number Train',
#   '10847:Number Train',
#   '60180:Monster Truck',
#   '70637:Cole - Spinjitzu Master'],
#  '98rating': 5.0,
#  99: ['31059:Sunset Street Bike',
#   "41151:Mulan's Training Day",
#   '45506:EV3 Color Sensor',
#   '60180:Monster Truck',
#   '70637:Cole - Spinjitzu Master',
#   '76096:Superman™ & Krypto™ Team-Up',
#   '40171:LEGO® Friends Buildable Hedgehog Storage',
#   '40171:LEGO® Friends Buildable Hedgehog Storage'],
#  '99rating': 5.0,
#  100: ['31059:Sunset Street Bike',
#   '42072:WHACK!',
#   '45506:EV3 Color Sensor',
#   '10847:Number Train',
#   '10847:Number Train',
#   '60180:Monster Truck',
#   '70637:Cole - Spinjitzu Master'],
#  '100rating': 5.0,
#  101: ['10592:Fire Truck',
#   '41323:Snow Resort Chalet',
#   "41316:Andrea's Speedboat Transporter",
#   '42072:WHACK!',
#   '45502:EV3 Large Servo Motor',
#   '45506:EV3 Color Sensor'],
#  '101rating': 5.0,
#  102: ['31059:Sunset Street Bike',
#   "41316:Andrea's Speedboat Transporter",
#   '40171:LEGO® Friends Buildable Hedgehog Storage',
#   '42072:WHACK!',
#   '31071:Drone Explorer',
#   '75887:Porsche 919 Hybrid',
#   '45502:EV3 Large Servo Motor'],
#  '102rating': 5.0,
#  103: ["41316:Andrea's Speedboat Transporter",
#   '10698:LEGO® Large Creative Brick Box',
#   '42072:WHACK!',
#   '45502:EV3 Large Servo Motor',
#   '45502:EV3 Large Servo Motor',
#   '45506:EV3 Color Sensor',
#   '10857:Piston Cup Race',
#   '10847:Number Train',
#   '10847:Number Train',
#   '10744:Thunder Hollow Crazy 8 Race'],
#  '103rating': 5.0,
#  104: ["41151:Mulan's Training Day",
#   '42072:WHACK!',
#   '45506:EV3 Color Sensor',
#   '10847:Number Train',
#   '10847:Number Train',
#   '60180:Monster Truck',
#   '70637:Cole - Spinjitzu Master',
#   '76096:Superman™ & Krypto™ Team-Up'],
#  '104rating': 5.0,
#  105: ["41316:Andrea's Speedboat Transporter",
#   '40171:LEGO® Friends Buildable Hedgehog Storage'],
#  '105rating': 5.0,
#  106: ['10592:Fire Truck',
#   "41151:Mulan's Training Day",
#   '42072:WHACK!',
#   '45506:EV3 Color Sensor',
#   '10847:Number Train',
#   '10847:Number Train',
#   '60180:Monster Truck',
#   '70637:Cole - Spinjitzu Master',
#   '76096:Superman™ & Krypto™ Team-Up',
#   '40171:LEGO® Friends Buildable Hedgehog Storage'],
#  '106rating': 5.0,
#  107: ["10732:Guido and Luigi's Pit Stop",
#   '41606:Star-Lord',
#   "10748:Emma's Pet Party",
#   "10732:Guido and Luigi's Pit Stop",
#   '31071:Drone Explorer',
#   '70637:Cole - Spinjitzu Master'],
#  '107rating': 5.0,
#  108: ['31059:Sunset Street Bike',
#   "41316:Andrea's Speedboat Transporter",
#   '42072:WHACK!',
#   '45502:EV3 Large Servo Motor',
#   '45506:EV3 Color Sensor',
#   '10857:Piston Cup Race',
#   '10847:Number Train',
#   '10847:Number Train',
#   '60180:Monster Truck'],
#  '108rating': 5.0,
#  109: ['31059:Sunset Street Bike',
#   "41316:Andrea's Speedboat Transporter",
#   '42072:WHACK!',
#   '45502:EV3 Large Servo Motor',
#   '45506:EV3 Color Sensor',
#   '10857:Piston Cup Race',
#   '10847:Number Train',
#   '70637:Cole - Spinjitzu Master',
#   '21143:The Nether Portal'],
#  '109rating': 5.0,
#  110: ['42072:WHACK!',
#   '45506:EV3 Color Sensor',
#   '10847:Number Train',
#   '60180:Monster Truck'],
#  '110rating': 5.0,
#  111: ['40171:LEGO® Friends Buildable Hedgehog Storage',
#   "10748:Emma's Pet Party",
#   '31071:Drone Explorer'],
#  '111rating': 5.0,
#  112: ['10592:Fire Truck',
#   "41316:Andrea's Speedboat Transporter",
#   '40171:LEGO® Friends Buildable Hedgehog Storage',
#   '42072:WHACK!',
#   '31071:Drone Explorer',
#   "10748:Emma's Pet Party"],
#  '112rating': 5.0,
#  113: ['40171:LEGO® Friends Buildable Hedgehog Storage', '42072:WHACK!'],
#  '113rating': 5.0,
#  114: ['31059:Sunset Street Bike',
#   '42072:WHACK!',
#   '10847:Number Train',
#   '40171:LEGO® Friends Buildable Hedgehog Storage',
#   '40171:LEGO® Friends Buildable Hedgehog Storage'],
#  '114rating': 5.0,
#  115: ["41316:Andrea's Speedboat Transporter",
#   '10698:LEGO® Large Creative Brick Box',
#   '42072:WHACK!',
#   '45502:EV3 Large Servo Motor',
#   '45502:EV3 Large Servo Motor',
#   '45506:EV3 Color Sensor',
#   '10857:Piston Cup Race',
#   '10847:Number Train'],
#  '115rating': 5.0,
#  116: ['10592:Fire Truck',
#   '41323:Snow Resort Chalet',
#   "41316:Andrea's Speedboat Transporter",
#   '42072:WHACK!',
#   '45502:EV3 Large Servo Motor',
#   '45506:EV3 Color Sensor',
#   '10857:Piston Cup Race',
#   '10847:Number Train',
#   '10847:Number Train',
#   '60180:Monster Truck'],
#  '116rating': 5.0,
#  117: ['40171:LEGO® Friends Buildable Hedgehog Storage',
#   "10748:Emma's Pet Party"],
#  '117rating': 5.0,
#  118: ["41151:Mulan's Training Day",
#   "41316:Andrea's Speedboat Transporter",
#   '40171:LEGO® Friends Buildable Hedgehog Storage',
#   '42072:WHACK!',
#   '71344:Excalibur Batman™ Fun Pack',
#   "10732:Guido and Luigi's Pit Stop",
#   '70637:Cole - Spinjitzu Master'],
#  '118rating': 5.0,
#  119: ['10592:Fire Truck',
#   '41323:Snow Resort Chalet',
#   "41316:Andrea's Speedboat Transporter",
#   '10698:LEGO® Large Creative Brick Box',
#   '42072:WHACK!',
#   '45502:EV3 Large Servo Motor'],
#  '119rating': 5.0,
#  120: ['10592:Fire Truck',
#   '41323:Snow Resort Chalet',
#   "41316:Andrea's Speedboat Transporter",
#   '10698:LEGO® Large Creative Brick Box',
#   '42072:WHACK!',
#   '45502:EV3 Large Servo Motor',
#   '45502:EV3 Large Servo Motor',
#   '45506:EV3 Color Sensor'],
#  '120rating': 5.0,
#  121: ['10592:Fire Truck',
#   '41323:Snow Resort Chalet',
#   "41316:Andrea's Speedboat Transporter",
#   '45502:EV3 Large Servo Motor',
#   '45506:EV3 Color Sensor',
#   '10857:Piston Cup Race',
#   '10847:Number Train',
#   '70637:Cole - Spinjitzu Master'],
#  '121rating': 5.0,
#  122: ['40171:LEGO® Friends Buildable Hedgehog Storage',
#   '42072:WHACK!',
#   "10748:Emma's Pet Party",
#   '31071:Drone Explorer'],
#  '122rating': 5.0,
#  123: ['10592:Fire Truck',
#   '31059:Sunset Street Bike',
#   "41316:Andrea's Speedboat Transporter",
#   '10698:LEGO® Large Creative Brick Box',
#   '42072:WHACK!',
#   '45502:EV3 Large Servo Motor',
#   '45502:EV3 Large Servo Motor'],
#  '123rating': 5.0,
#  124: ['40171:LEGO® Friends Buildable Hedgehog Storage',
#   "10748:Emma's Pet Party"],
#  '124rating': 5.0,
#  125: ['40171:LEGO® Friends Buildable Hedgehog Storage'],
#  '125rating': 5.0,
#  126: ['10592:Fire Truck',
#   '41323:Snow Resort Chalet',
#   "41316:Andrea's Speedboat Transporter",
#   '40171:LEGO® Friends Buildable Hedgehog Storage',
#   '42072:WHACK!',
#   '31071:Drone Explorer'],
#  '126rating': 5.0,
#  127: ['10592:Fire Truck',
#   "41316:Andrea's Speedboat Transporter",
#   '42072:WHACK!',
#   '45502:EV3 Large Servo Motor',
#   '45506:EV3 Color Sensor'],
#  '127rating': 5.0,
#  128: ['40171:LEGO® Friends Buildable Hedgehog Storage',
#   "10748:Emma's Pet Party",
#   '40171:LEGO® Friends Buildable Hedgehog Storage'],
#  '128rating': 5.0,
#  129: ["41316:Andrea's Speedboat Transporter",
#   '40171:LEGO® Friends Buildable Hedgehog Storage'],
#  '129rating': 5.0,
#  130: ["41151:Mulan's Training Day",
#   '45506:EV3 Color Sensor',
#   '60180:Monster Truck',
#   '70637:Cole - Spinjitzu Master',
#   '40171:LEGO® Friends Buildable Hedgehog Storage',
#   '40171:LEGO® Friends Buildable Hedgehog Storage',
#   "41151:Mulan's Training Day"],
#  '130rating': 5.0,
#  131: ['31059:Sunset Street Bike',
#   '41323:Snow Resort Chalet',
#   "41316:Andrea's Speedboat Transporter",
#   '42072:WHACK!',
#   '45502:EV3 Large Servo Motor',
#   '45506:EV3 Color Sensor',
#   '10857:Piston Cup Race'],
#  '131rating': 5.0,
#  132: ['10592:Fire Truck',
#   "41316:Andrea's Speedboat Transporter",
#   '42072:WHACK!',
#   '45502:EV3 Large Servo Motor',
#   '45506:EV3 Color Sensor'],
#  '132rating': 5.0,
#  133: ['40171:LEGO® Friends Buildable Hedgehog Storage',
#   "10748:Emma's Pet Party"],
#  '133rating': 5.0,
#  134: ['40171:LEGO® Friends Buildable Hedgehog Storage', '42072:WHACK!'],
#  '134rating': 5.0,
#  135: ['41323:Snow Resort Chalet',
#   "41316:Andrea's Speedboat Transporter",
#   '42072:WHACK!',
#   '45502:EV3 Large Servo Motor',
#   '45506:EV3 Color Sensor',
#   '10857:Piston Cup Race',
#   '10847:Number Train',
#   '10847:Number Train',
#   '60180:Monster Truck',
#   '70637:Cole - Spinjitzu Master'],
#  '135rating': 5.0,
#  136: ["41316:Andrea's Speedboat Transporter"],
#  '136rating': 5.0,
#  137: ['31059:Sunset Street Bike',
#   '41323:Snow Resort Chalet',
#   "41316:Andrea's Speedboat Transporter",
#   '42072:WHACK!',
#   '45502:EV3 Large Servo Motor',
#   '45506:EV3 Color Sensor',
#   '10857:Piston Cup Race'],
#  '137rating': 5.0,
#  138: ['40171:LEGO® Friends Buildable Hedgehog Storage',
#   '42072:WHACK!',
#   "10748:Emma's Pet Party"],
#  '138rating': 5.0,
#  139: ["10732:Guido and Luigi's Pit Stop",
#   "10748:Emma's Pet Party",
#   '31071:Drone Explorer',
#   '70637:Cole - Spinjitzu Master'],
#  '139rating': 5.0,
#  140: ['10592:Fire Truck',
#   '31059:Sunset Street Bike',
#   '41323:Snow Resort Chalet',
#   "41316:Andrea's Speedboat Transporter",
#   '10698:LEGO® Large Creative Brick Box',
#   '42072:WHACK!',
#   '45502:EV3 Large Servo Motor'],
#  '140rating': 5.0,
#  141: ['10592:Fire Truck',
#   '31059:Sunset Street Bike',
#   '42072:WHACK!',
#   '45506:EV3 Color Sensor',
#   '10847:Number Train',
#   '10847:Number Train',
#   '60180:Monster Truck'],
#  '141rating': 5.0,
#  142: ['40171:LEGO® Friends Buildable Hedgehog Storage',
#   '31071:Drone Explorer'],
#  '142rating': 5.0,
#  143: ["41316:Andrea's Speedboat Transporter"],
#  '143rating': 5.0,
#  144: ['10592:Fire Truck',
#   '31059:Sunset Street Bike',
#   '41323:Snow Resort Chalet',
#   "41316:Andrea's Speedboat Transporter",
#   '10698:LEGO® Large Creative Brick Box',
#   '42072:WHACK!',
#   '45502:EV3 Large Servo Motor',
#   '45502:EV3 Large Servo Motor',
#   '45506:EV3 Color Sensor'],
#  '144rating': 5.0,
#  145: ['10592:Fire Truck',
#   '31059:Sunset Street Bike',
#   '41323:Snow Resort Chalet',
#   "41316:Andrea's Speedboat Transporter",
#   '42072:WHACK!'],
#  '145rating': 5.0,
#  146: ["41316:Andrea's Speedboat Transporter"],
#  '146rating': 5.0,
#  147: ['10592:Fire Truck',
#   '31059:Sunset Street Bike',
#   '41323:Snow Resort Chalet',
#   "41316:Andrea's Speedboat Transporter",
#   '42072:WHACK!',
#   '45502:EV3 Large Servo Motor'],
#  '147rating': 5.0,
#  148: ['10592:Fire Truck',
#   "41316:Andrea's Speedboat Transporter",
#   '42072:WHACK!',
#   '10813:Big Construction Site',
#   '70637:Cole - Spinjitzu Master',
#   '76096:Superman™ & Krypto™ Team-Up'],
#  '148rating': 5.0,
#  149: ['42072:WHACK!',
#   '45506:EV3 Color Sensor',
#   "10748:Emma's Pet Party",
#   '31071:Drone Explorer'],
#  '149rating': 5.0,
#  150: ['10592:Fire Truck',
#   '41323:Snow Resort Chalet',
#   "41316:Andrea's Speedboat Transporter",
#   '45502:EV3 Large Servo Motor',
#   '45506:EV3 Color Sensor',
#   '10857:Piston Cup Race',
#   '10847:Number Train',
#   '70637:Cole - Spinjitzu Master',
#   '21143:The Nether Portal'],
#  '150rating': 5.0,
#  151: ['10592:Fire Truck',
#   '31059:Sunset Street Bike',
#   "41316:Andrea's Speedboat Transporter",
#   '42072:WHACK!',
#   '45502:EV3 Large Servo Motor',
#   '70637:Cole - Spinjitzu Master',
#   '31071:Drone Explorer'],
#  '151rating': 5.0,
#  152: ['40171:LEGO® Friends Buildable Hedgehog Storage',
#   '31071:Drone Explorer',
#   "10748:Emma's Pet Party"],
#  '152rating': 5.0,
#  153: ['31059:Sunset Street Bike',
#   '41323:Snow Resort Chalet',
#   "41316:Andrea's Speedboat Transporter",
#   '45502:EV3 Large Servo Motor',
#   '45506:EV3 Color Sensor',
#   '10857:Piston Cup Race',
#   '60180:Monster Truck',
#   '70637:Cole - Spinjitzu Master',
#   '76096:Superman™ & Krypto™ Team-Up'],
#  '153rating': 5.0,
#  154: ['10592:Fire Truck',
#   '31059:Sunset Street Bike',
#   '41323:Snow Resort Chalet',
#   "41316:Andrea's Speedboat Transporter",
#   '42072:WHACK!',
#   '45502:EV3 Large Servo Motor',
#   '45506:EV3 Color Sensor'],
#  '154rating': 5.0,
#  155: ['10592:Fire Truck',
#   '31059:Sunset Street Bike',
#   "41151:Mulan's Training Day",
#   '42072:WHACK!',
#   '45506:EV3 Color Sensor',
#   '10847:Number Train',
#   '10847:Number Train',
#   '60180:Monster Truck',
#   '70637:Cole - Spinjitzu Master',
#   '76096:Superman™ & Krypto™ Team-Up'],
#  '155rating': 5.0,
#  156: ['10592:Fire Truck',
#   '31059:Sunset Street Bike',
#   '41323:Snow Resort Chalet',
#   "41316:Andrea's Speedboat Transporter",
#   '42072:WHACK!',
#   '45502:EV3 Large Servo Motor',
#   '45506:EV3 Color Sensor',
#   '10857:Piston Cup Race'],
#  '156rating': 5.0,
#  157: ['10592:Fire Truck',
#   '31059:Sunset Street Bike',
#   '42072:WHACK!',
#   '45506:EV3 Color Sensor',
#   '10847:Number Train',
#   '10847:Number Train',
#   '60180:Monster Truck'],
#  '157rating': 5.0,
#  158: ['10592:Fire Truck',
#   '31059:Sunset Street Bike',
#   '42072:WHACK!',
#   '45506:EV3 Color Sensor',
#   '10847:Number Train'],
#  '158rating': 5.0,
#  159: ["41316:Andrea's Speedboat Transporter",
#   '40171:LEGO® Friends Buildable Hedgehog Storage',
#   '42072:WHACK!',
#   '31071:Drone Explorer',
#   "10748:Emma's Pet Party",
#   '70637:Cole - Spinjitzu Master'],
#  '159rating': 5.0,
#  160: ['10592:Fire Truck',
#   '31059:Sunset Street Bike',
#   "41316:Andrea's Speedboat Transporter",
#   '42072:WHACK!',
#   '45506:EV3 Color Sensor',
#   '10857:Piston Cup Race',
#   '10847:Number Train',
#   '10847:Number Train',
#   '60180:Monster Truck',
#   '70637:Cole - Spinjitzu Master'],
#  '160rating': 5.0,
#  161: ['10592:Fire Truck',
#   '31059:Sunset Street Bike',
#   "41316:Andrea's Speedboat Transporter",
#   '10698:LEGO® Large Creative Brick Box',
#   '42072:WHACK!'],
#  '161rating': 5.0,
#  162: ["41316:Andrea's Speedboat Transporter",
#   '40171:LEGO® Friends Buildable Hedgehog Storage',
#   '42072:WHACK!',
#   "10748:Emma's Pet Party"],
#  '162rating': 5.0,
#  163: ['31059:Sunset Street Bike',
#   "41151:Mulan's Training Day",
#   '42072:WHACK!',
#   '45506:EV3 Color Sensor',
#   '10847:Number Train',
#   '10847:Number Train',
#   '60180:Monster Truck',
#   '70637:Cole - Spinjitzu Master',
#   '40171:LEGO® Friends Buildable Hedgehog Storage'],
#  '163rating': 5.0,
#  164: ['10592:Fire Truck',
#   '31059:Sunset Street Bike',
#   '41323:Snow Resort Chalet',
#   "41316:Andrea's Speedboat Transporter",
#   '10698:LEGO® Large Creative Brick Box',
#   '42072:WHACK!'],
#  '164rating': 5.0,
#  165: ["41316:Andrea's Speedboat Transporter",
#   '40171:LEGO® Friends Buildable Hedgehog Storage',
#   '42072:WHACK!',
#   '31071:Drone Explorer'],
#  '165rating': 5.0,
#  166: ['10592:Fire Truck',
#   '31059:Sunset Street Bike',
#   '41323:Snow Resort Chalet',
#   "41316:Andrea's Speedboat Transporter",
#   '42072:WHACK!',
#   '45502:EV3 Large Servo Motor'],
#  '166rating': 5.0,
#  167: ['10592:Fire Truck',
#   "41151:Mulan's Training Day",
#   '45506:EV3 Color Sensor',
#   '10847:Number Train',
#   '70637:Cole - Spinjitzu Master',
#   '40171:LEGO® Friends Buildable Hedgehog Storage'],
#  '167rating': 5.0,
#  168: ["41316:Andrea's Speedboat Transporter",
#   '40171:LEGO® Friends Buildable Hedgehog Storage',
#   '42072:WHACK!',
#   '75887:Porsche 919 Hybrid',
#   "10732:Guido and Luigi's Pit Stop",
#   '41606:Star-Lord',
#   "10748:Emma's Pet Party",
#   '40171:LEGO® Friends Buildable Hedgehog Storage',
#   '70637:Cole - Spinjitzu Master'],
#  '168rating': 5.0,
#  169: ["10732:Guido and Luigi's Pit Stop",
#   "10748:Emma's Pet Party",
#   '31071:Drone Explorer',
#   '70637:Cole - Spinjitzu Master'],
#  '169rating': 5.0,
#  170: ['10592:Fire Truck',
#   '31059:Sunset Street Bike',
#   '41323:Snow Resort Chalet',
#   "41316:Andrea's Speedboat Transporter",
#   '10698:LEGO® Large Creative Brick Box',
#   '42072:WHACK!',
#   '45502:EV3 Large Servo Motor',
#   '45502:EV3 Large Servo Motor',
#   '10857:Piston Cup Race',
#   '10847:Number Train'],
#  '170rating': 5.0,
#  171: ['40171:LEGO® Friends Buildable Hedgehog Storage'],
#  '171rating': 5.0,
#  172: ['31059:Sunset Street Bike',
#   '41323:Snow Resort Chalet',
#   "41316:Andrea's Speedboat Transporter",
#   '45502:EV3 Large Servo Motor',
#   '45506:EV3 Color Sensor',
#   '10857:Piston Cup Race',
#   '60180:Monster Truck',
#   '70637:Cole - Spinjitzu Master',
#   '76096:Superman™ & Krypto™ Team-Up'],
#  '172rating': 5.0,
#  173: ["41316:Andrea's Speedboat Transporter"],
#  '173rating': 5.0,
#  174: ['40171:LEGO® Friends Buildable Hedgehog Storage',
#   '31071:Drone Explorer'],
#  '174rating': 5.0,
#  175: ["41316:Andrea's Speedboat Transporter",
#   '40171:LEGO® Friends Buildable Hedgehog Storage',
#   '42072:WHACK!',
#   '31071:Drone Explorer',
#   "10748:Emma's Pet Party",
#   '70637:Cole - Spinjitzu Master'],
#  '175rating': 5.0,
#  176: ['42072:WHACK!',
#   "10748:Emma's Pet Party",
#   '31071:Drone Explorer',
#   '70637:Cole - Spinjitzu Master'],
#  '176rating': 5.0,
#  177: ['31071:Drone Explorer', '75887:Porsche 919 Hybrid'],
#  '177rating': 5.0,
#  178: ['10592:Fire Truck',
#   "41316:Andrea's Speedboat Transporter",
#   '40171:LEGO® Friends Buildable Hedgehog Storage',
#   '42072:WHACK!',
#   '31071:Drone Explorer',
#   "10748:Emma's Pet Party"],
#  '178rating': 5.0,
#  179: ['10592:Fire Truck',
#   '31059:Sunset Street Bike',
#   "41151:Mulan's Training Day",
#   '42072:WHACK!',
#   '45506:EV3 Color Sensor',
#   '10847:Number Train',
#   '10847:Number Train',
#   '60180:Monster Truck',
#   '70637:Cole - Spinjitzu Master',
#   '76096:Superman™ & Krypto™ Team-Up'],
#  '179rating': 5.0,
#  180: ["41316:Andrea's Speedboat Transporter",
#   '40171:LEGO® Friends Buildable Hedgehog Storage',
#   "10748:Emma's Pet Party",
#   '31071:Drone Explorer'],
#  '180rating': 5.0,
#  181: ['40171:LEGO® Friends Buildable Hedgehog Storage',
#   "10748:Emma's Pet Party"],
#  '181rating': 5.0,
#  182: ['31059:Sunset Street Bike',
#   "41151:Mulan's Training Day",
#   '45506:EV3 Color Sensor',
#   '60180:Monster Truck',
#   '70637:Cole - Spinjitzu Master',
#   '76096:Superman™ & Krypto™ Team-Up'],
#  '182rating': 5.0,
#  183: ['40171:LEGO® Friends Buildable Hedgehog Storage'],
#  '183rating': 5.0,
#  184: ['40171:LEGO® Friends Buildable Hedgehog Storage',
#   '31071:Drone Explorer',
#   "10748:Emma's Pet Party"],
#  '184rating': 5.0,
#  185: ['10592:Fire Truck',
#   '31059:Sunset Street Bike',
#   '41323:Snow Resort Chalet',
#   "41316:Andrea's Speedboat Transporter",
#   '42072:WHACK!',
#   '45502:EV3 Large Servo Motor',
#   '45506:EV3 Color Sensor',
#   '10857:Piston Cup Race'],
#  '185rating': 5.0,
#  186: ['40171:LEGO® Friends Buildable Hedgehog Storage',
#   "10748:Emma's Pet Party"],
#  '186rating': 5.0,
#  187: ['42072:WHACK!', "10748:Emma's Pet Party"],
#  '187rating': 5.0,
#  188: ['10592:Fire Truck',
#   '31059:Sunset Street Bike',
#   '41323:Snow Resort Chalet',
#   "41316:Andrea's Speedboat Transporter",
#   '42072:WHACK!',
#   '45502:EV3 Large Servo Motor',
#   '45506:EV3 Color Sensor',
#   '10857:Piston Cup Race',
#   '10847:Number Train',
#   '10847:Number Train'],
#  '188rating': 5.0,
#  189: ['31059:Sunset Street Bike',
#   '41323:Snow Resort Chalet',
#   "41316:Andrea's Speedboat Transporter",
#   '42072:WHACK!',
#   '45502:EV3 Large Servo Motor',
#   '45506:EV3 Color Sensor',
#   '10857:Piston Cup Race',
#   '60180:Monster Truck',
#   '70637:Cole - Spinjitzu Master'],
#  '189rating': 5.0,
#  190: ['40171:LEGO® Friends Buildable Hedgehog Storage',
#   '31071:Drone Explorer'],
#  '190rating': 5.0,
#  191: ['31071:Drone Explorer'],
#  '191rating': 5.0,
#  192: ['10592:Fire Truck',
#   "41151:Mulan's Training Day",
#   '45506:EV3 Color Sensor',
#   '10847:Number Train',
#   '70637:Cole - Spinjitzu Master'],
#  '192rating': 5.0,
#  193: ["41316:Andrea's Speedboat Transporter",
#   '40171:LEGO® Friends Buildable Hedgehog Storage',
#   '42072:WHACK!',
#   '31071:Drone Explorer'],
#  '193rating': 5.0,
#  194: ['40171:LEGO® Friends Buildable Hedgehog Storage',
#   '42072:WHACK!',
#   "10748:Emma's Pet Party",
#   '70637:Cole - Spinjitzu Master'],
#  '194rating': 5.0,
#  195: ['40171:LEGO® Friends Buildable Hedgehog Storage',
#   '42072:WHACK!',
#   "10748:Emma's Pet Party",
#   '70637:Cole - Spinjitzu Master'],
#  '195rating': 5.0,
#  196: ["41316:Andrea's Speedboat Transporter",
#   '40171:LEGO® Friends Buildable Hedgehog Storage',
#   "10748:Emma's Pet Party",
#   '70637:Cole - Spinjitzu Master'],
#  '196rating': 5.0,
#  197: ['10592:Fire Truck',
#   '41323:Snow Resort Chalet',
#   "41316:Andrea's Speedboat Transporter",
#   '10698:LEGO® Large Creative Brick Box',
#   '45502:EV3 Large Servo Motor',
#   '45502:EV3 Large Servo Motor',
#   '45506:EV3 Color Sensor',
#   '10857:Piston Cup Race',
#   '10847:Number Train',
#   '10744:Thunder Hollow Crazy 8 Race'],
#  '197rating': 5.0,
#  198: ['31059:Sunset Street Bike',
#   "41151:Mulan's Training Day",
#   '45506:EV3 Color Sensor',
#   '10847:Number Train',
#   '10847:Number Train',
#   '60180:Monster Truck',
#   '70637:Cole - Spinjitzu Master',
#   '40171:LEGO® Friends Buildable Hedgehog Storage',
#   '40171:LEGO® Friends Buildable Hedgehog Storage',
#   "41151:Mulan's Training Day"],
#  '198rating': 5.0,
#  199: ['10592:Fire Truck',
#   '31059:Sunset Street Bike',
#   '41323:Snow Resort Chalet',
#   "41316:Andrea's Speedboat Transporter",
#   '10698:LEGO® Large Creative Brick Box',
#   '42072:WHACK!'],
#  '199rating': 5.0,
#  200: ["41316:Andrea's Speedboat Transporter",
#   '40171:LEGO® Friends Buildable Hedgehog Storage',
#   '42072:WHACK!'],
#  '200rating': 5.0}
